# %%
import pandas as pd

# %%
df =pd.read_csv("C://Users//Acorz//Desktop//simpli//Data science doc//houseprice.csv")

# %%
df.head()
# Out:
#         Date    price  Bedroom  Bathroom   sqrt_lot  floor  waterfront  view  \
# 0  5/22/2022    30000        5        2.0      1500    2.0           0     0
# 1  5/23/2022    30022        9        3.0      2342    1.0           0     4
# 2  5/24/2022  3000220        7        4.0      2555    2.0           0     0
# 3  5/25/2022    50000        5        NaN      1456    1.0           0     0
# 4  5/26/2022   540000        4        6.0      1135    3.0           0     0
#
#    condition    sqft_above  sqft_basement  yr_built  yr_renovated  street  \
# 0            3        1400              0      2000             0      kl
# 1            5        3233            280      2032             0      kl
# 2            7        1334              0      2012             0      tn
# 3            8        3113           1000      2011             0      an
# 4            8        2233              3      2004             0      tn
#
#         city  statezip country
# ...

# %%
df.columns
# Out:
# Index(['Date', 'price', 'Bedroom', 'Bathroom ', 'sqrt_lot', 'floor',
#        'waterfront', 'view', 'condition  ', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', ' street', 'city', 'statezip', 'country'],
#       dtype='object')

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
#we find the differrent columns plotting

# %%
df["price"].plot()
# Out:
# <AxesSubplot: >

# %%
df["Bedroom"].plot()
# Out:
# <AxesSubplot: >

# %%
df["price"].plot()
# Out:
# <AxesSubplot: >

# %%
df.plot(x='price',y='Bedroom',kind='scatter' , legend =True)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Bedroom'>

# %%
#change the figure size

df.plot(title="house plot",x = 'price',y = "Bedroom" ,kind = 'scatter', figsize=(15,10))
# Out:
# <AxesSubplot: title={'center': 'house plot'}, xlabel='price', ylabel='Bedroom'>

# %%
df['price'].plot(title="box plot",kind='box',figsize=(13,10))
# Out:
# <AxesSubplot: title={'center': 'box plot'}>

# %%
df['price'].plot(title="histogram",kind="hist",)
# Out:
# <AxesSubplot: title={'center': 'histogram'}, ylabel='Frequency'>

# %%
df
# Out:
#         Date    price  Bedroom  Bathroom   sqrt_lot  floor  waterfront  view  \
# 0  5/22/2022    30000        5        2.0      1500    2.0           0     0
# 1  5/23/2022    30022        9        3.0      2342    1.0           0     4
# 2  5/24/2022  3000220        7        4.0      2555    2.0           0     0
# 3  5/25/2022    50000        5        NaN      1456    1.0           0     0
# 4  5/26/2022   540000        4        6.0      1135    3.0           0     0
# 5  5/27/2022    60000        3        8.0      4488    2.5           0     0
#
#    condition    sqft_above  sqft_basement  yr_built  yr_renovated  street  \
# 0            3        1400              0      2000             0      kl
# 1            5        3233            280      2032             0      kl
# 2            7        1334              0      2012             0      tn
# 3            8        3113           1000      2011             0      an
# ...
